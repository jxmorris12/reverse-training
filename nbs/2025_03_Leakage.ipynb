# %%
# autoreload
# %load_ext autoreload
# %autoreload 2

# fix path
import sys
sys.path.append("/home/jxm/reverse-training")
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from utils.analysis import load_results_as_df
import os


HOME_DIR = "/home/jxm/reverse-training"
df = load_results_as_df(os.path.join(HOME_DIR, "results", "03-26-exp-leakage-4"))
df["seed_dataset_size"] = df["select_seed_dataset"].str.extract(r"(\d+)").astype(int)
# Out:
# Found 131 files in /home/jxm/reverse-training/results/03-26-exp-leakage-4/*.pkl
# Filtered 0/131 results with no evaluation metrics
# dict_keys(['data', 'full_ot_distance', 'sinkhorn_distance', 'jaccard_overlap_examples', 'jaccard_overlap_vocabulary', 'levenshtein_stats', 'args', 'expert_evaluation_metrics', 'evaluation_metrics'])

# %%
import pandas as pd

pd.set_option('display.max_rows', None)

dv_cols = ["dataset", "select_seed_dataset", "select_full_dataset_size", "select_batch_fill_strategy"]

iv_cols = ["evaluation_best_eval_accuracy", "dataset_sinkhorn_distance", "dataset_full_ot_distance", "dataset_jaccard_overlap_vocabulary"]

# final_df = df[df["select_seed_dataset"] == "nq_500000"]

df.groupby(dv_cols)[iv_cols].mean().sort_values(
    by=["dataset","select_seed_dataset", "select_full_dataset_size", "select_batch_fill_strategy"], 
    ascending=False
)
# Out:
#                                                                                         evaluation_best_eval_accuracy  \
# dataset       select_seed_dataset  select_full_dataset_size select_batch_fill_strategy
# ag_news_10000 nq_9000 ag_news_1000 1000                     topk_balanced                                    0.696289
#                                                             topk                                             0.508057
#                                                             random                                           0.699219
#                                                             greedy_batched                                   0.780924
#               nq_8000 ag_news_2000 1000                     topk_balanced                                    0.708984
#                                                             topk                                             0.542969
#                                                             random                                           0.715820
#                                                             greedy_batched                                   0.774089
#               nq_7000 ag_news_3000 1000                     topk_balanced                                    0.725749
#                                                             topk                                             0.542969
#                                                             random                                           0.736003
#                                                             greedy_batched                                   0.778158
#               nq_6000 ag_news_4000 1000                     topk_balanced                                    0.728190
#                                                             topk                                             0.582845
#                                                             random                                           0.760579
#                                                             greedy_batched                                   0.786296
#               nq_5000 ag_news_5000 1000                     topk_balanced                                    0.746582
#                                                             topk                                             0.555013
#                                                             random                                           0.775065
#                                                             greedy_batched                                   0.788086
#               nq_4000 ag_news_6000 1000                     topk_balanced                                    0.752441
#                                                             topk                                             0.549805
#                                                             random                                           0.775553
#                                                             greedy_batched                                   0.777669
#               nq_3000 ag_news_7000 1000                     topk_balanced                                    0.739909
#                                                             topk                                             0.542806
#                                                             random                                           0.791829
#                                                             greedy_batched                                   0.783691
#               nq_2000 ag_news_8000 1000                     topk_balanced                                    0.732910
#                                                             topk                                             0.577474
#                                                             random                                           0.783691
#                                                             greedy_batched                                   0.777669
#               nq_10000             1000                     topk_balanced                                    0.622233
#                                                             topk                                             0.439616
#                                                             random                                           0.647949
#                                                             greedy_batched                                   0.746582
#               nq_1000 ag_news_9000 1000                     topk_balanced                                    0.761230
#                                                             topk                                             0.581706
#                                                             random                                           0.800130
#                                                             greedy_batched                                   0.786784
#               ag_news_10000        1000                     topk_balanced                                    0.755208
#                                                             topk                                             0.562663
#                                                             random                                           0.791341
#                                                             greedy_batched                                   0.776530
#
#                                                                                         dataset_sinkhorn_distance  \
# dataset       select_seed_dataset  select_full_dataset_size select_batch_fill_strategy
# ag_news_10000 nq_9000 ag_news_1000 1000                     topk_balanced                                1.250686
#                                                             topk                                         1.252237
#                                                             random                                       1.259274
#                                                             greedy_batched                               1.196099
#               nq_8000 ag_news_2000 1000                     topk_balanced                                1.217328
#                                                             topk                                         1.225592
#                                                             random                                       1.227735
#                                                             greedy_batched                               1.152924
#               nq_7000 ag_news_3000 1000                     topk_balanced                                1.190961
#                                                             topk                                         1.194267
#                                                             random                                       1.194490
#                                                             greedy_batched                               1.134495
#               nq_6000 ag_news_4000 1000                     topk_balanced                                1.160471
#                                                             topk                                         1.168622
#                                                             random                                       1.163976
#                                                             greedy_batched                               1.102610
#               nq_5000 ag_news_5000 1000                     topk_balanced                                1.132027
#                                                             topk                                         1.140831
#                                                             random                                       1.132835
#                                                             greedy_batched                               1.087209
#               nq_4000 ag_news_6000 1000                     topk_balanced                                1.111477
#                                                             topk                                         1.119400
#                                                             random                                       1.103714
#                                                             greedy_batched                               1.068481
#               nq_3000 ag_news_7000 1000                     topk_balanced                                1.084869
#                                                             topk                                         1.097580
#                                                             random                                       1.074399
#                                                             greedy_batched                               1.050134
#               nq_2000 ag_news_8000 1000                     topk_balanced                                1.056693
#                                                             topk                                         1.071540
#                                                             random                                       1.046908
#                                                             greedy_batched                               1.033399
#               nq_10000             1000                     topk_balanced                                1.291524
#                                                             topk                                         1.297859
#                                                             random                                       1.293000
#                                                             greedy_batched                               1.273995
#               nq_1000 ag_news_9000 1000                     topk_balanced                                1.029390
#                                                             topk                                         1.053705
#                                                             random                                       1.018992
#                                                             greedy_batched                               1.013186
#               ag_news_10000        1000                     topk_balanced                                0.998778
#                                                             topk                                         1.039270
#                                                             random                                       0.989390
#                                                             greedy_batched                               0.996602
#
#                                                                                         dataset_full_ot_distance  \
# dataset       select_seed_dataset  select_full_dataset_size select_batch_fill_strategy
# ag_news_10000 nq_9000 ag_news_1000 1000                     topk_balanced                               1.014474
#                                                             topk                                        1.016650
#                                                             random                                      1.022879
#                                                             greedy_batched                              0.956676
#               nq_8000 ag_news_2000 1000                     topk_balanced                               0.981844
#                                                             topk                                        0.991777
#                                                             random                                      0.991126
#                                                             greedy_batched                              0.914316
#               nq_7000 ag_news_3000 1000                     topk_balanced                               0.955966
#                                                             topk                                        0.961092
#                                                             random                                      0.957401
#                                                             greedy_batched                              0.895917
#               nq_6000 ag_news_4000 1000                     topk_balanced                               0.925206
#                                                             topk                                        0.936066
#                                                             random                                      0.926793
#                                                             greedy_batched                              0.863956
#               nq_5000 ag_news_5000 1000                     topk_balanced                               0.897218
#                                                             topk                                        0.909798
#                                                             random                                      0.895127
#                                                             greedy_batched                              0.849181
#               nq_4000 ag_news_6000 1000                     topk_balanced                               0.876562
#                                                             topk                                        0.889895
#                                                             random                                      0.865258
#                                                             greedy_batched                              0.829813
#               nq_3000 ag_news_7000 1000                     topk_balanced                               0.850263
#                                                             topk                                        0.869976
#                                                             random                                      0.835976
#                                                             greedy_batched                              0.812914
#               nq_2000 ag_news_8000 1000                     topk_balanced                               0.822242
#                                                             topk                                        0.845883
#                                                             random                                      0.807707
#                                                             greedy_batched                              0.797272
#               nq_10000             1000                     topk_balanced                               1.054169
#                                                             topk                                        1.061552
#                                                             random                                      1.055406
#                                                             greedy_batched                              1.032188
#               nq_1000 ag_news_9000 1000                     topk_balanced                               0.797105
#                                                             topk                                        0.831587
#                                                             random                                      0.781122
#                                                             greedy_batched                              0.778044
#               ag_news_10000        1000                     topk_balanced                               0.769009
#                                                             topk                                        0.820360
#                                                             random                                      0.752627
#                                                             greedy_batched                              0.763578
#
#                                                                                         dataset_jaccard_overlap_vocabulary
# dataset       select_seed_dataset  select_full_dataset_size select_batch_fill_strategy
# ag_news_10000 nq_9000 ag_news_1000 1000                     topk_balanced                                         0.371705
#                                                             topk                                                  0.371840
#                                                             random                                                0.371583
#                                                             greedy_batched                                        0.378583
#               nq_8000 ag_news_2000 1000                     topk_balanced                                         0.378783
#                                                             topk                                                  0.376776
#                                                             random                                                0.381290
#                                                             greedy_batched                                        0.387801
#               nq_7000 ag_news_3000 1000                     topk_balanced                                         0.384013
#                                                             topk                                                  0.381472
#                                                             random                                                0.387243
#                                                             greedy_batched                                        0.389558
#               nq_6000 ag_news_4000 1000                     topk_balanced                                         0.385806
#                                                             topk                                                  0.383467
#                                                             random                                                0.391551
#                                                             greedy_batched                                        0.389324
#               nq_5000 ag_news_5000 1000                     topk_balanced                                         0.390051
#                                                             topk                                                  0.383656
#                                                             random                                                0.393198
#                                                             greedy_batched                                        0.392062
#               nq_4000 ag_news_6000 1000                     topk_balanced                                         0.390535
#                                                             topk                                                  0.384061
#                                                             random                                                0.397585
#                                                             greedy_batched                                        0.388102
#               nq_3000 ag_news_7000 1000                     topk_balanced                                         0.390281
#                                                             topk                                                  0.383005
#                                                             random                                                0.395709
#                                                             greedy_batched                                        0.392588
#               nq_2000 ag_news_8000 1000                     topk_balanced                                         0.388657
#                                                             topk                                                  0.377032
#                                                             random                                                0.395917
#                                                             greedy_batched                                        0.393271
#               nq_10000             1000                     topk_balanced                                         0.355415
#                                                             topk                                                  0.357519
#                                                             random                                                0.359130
#                                                             greedy_batched                                        0.357902
#               nq_1000 ag_news_9000 1000                     topk_balanced                                         0.386849
#                                                             topk                                                  0.370072
#                                                             random                                                0.391118
#                                                             greedy_batched                                        0.388070
#               ag_news_10000        1000                     topk_balanced                                         0.381814
#                                                             topk                                                  0.361293
#                                                             random                                                0.384533
#                                                             greedy_batched                                        0.385408

# %%
df["select_seed_dataset"].value_counts()
# Out:
# select_seed_dataset
# nq_4000 ag_news_6000    12
# nq_6000 ag_news_4000    12
# nq_10000                12
# nq_5000 ag_news_5000    12
# ag_news_10000           12
# nq_2000 ag_news_8000    12
# nq_7000 ag_news_3000    12
# nq_1000 ag_news_9000    12
# nq_8000 ag_news_2000    12
# nq_3000 ag_news_7000    12
# nq_9000 ag_news_1000    11
# Name: count, dtype: int64

# %%
import functools
import re

def extract_size(prefix: str, x: str):  
    try:
        return int(re.search(rf"{prefix}_(\d+)", x).group(1))
    except:
        return 0

df["nq_size"] = df["select_seed_dataset"].apply(functools.partial(extract_size, "nq"))
df["ag_news_size"] = df["select_seed_dataset"].apply(functools.partial(extract_size, "ag_news"))

df["ratio"] = 1.0 - df["nq_size"] / df["nq_size"].max()
df["ratio"].value_counts()
# Out:
# ratio
# 0.6    12
# 0.4    12
# 0.0    12
# 0.5    12
# 1.0    12
# 0.8    12
# 0.3    12
# 0.9    12
# 0.2    12
# 0.7    12
# 0.1    11
# Name: count, dtype: int64

# %%
dv_cols = ["ratio"]

iv_cols = ["evaluation_best_eval_accuracy", "dataset_full_ot_distance"]


# Final results: dataset size 1000, batch fill strategy is not bottomk
fig, ax1 = plt.subplots(figsize=(8, 5))

# Plot first line (accuracy) on primary y-axis
sns.lineplot(data=df, x="ratio", y="evaluation_best_eval_accuracy", ax=ax1)
ax1.set_xlabel('Leakage %')
ax1.set_ylabel('Accuracy', color='blue')
ax1.tick_params(axis='y', labelcolor='blue')

# Create secondary y-axis and plot second line (OT distance)
ax2 = ax1.twinx()
sns.lineplot(data=df, x="ratio", y="dataset_full_ot_distance", ax=ax2, color="red")
ax2.set_ylabel('OT Distance', color='red')
ax2.tick_params(axis='y', labelcolor='red')

# Add title and legend
fig.legend(loc='upper right', bbox_to_anchor=(1, 0.9))

plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_3555751/2220622030.py:22: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   fig.legend(loc='upper right', bbox_to_anchor=(1, 0.9))
# findfont: Font family 'Helvetica Neue LT Pro' not found.
# findfont: Font family 'Helvetica Neue LT Pro' not found.
# findfont: Font family 'Helvetica Neue LT Pro' not found.
# findfont: Font family 'Helvetica Neue LT Pro' not found.
# findfont: Font family 'Helvetica Neue LT Pro' not found.
# findfont: Font family 'Helvetica Neue LT Pro' not found.
# findfont: Font family 'Helvetica Neue LT Pro' not found.
# findfont: Font family 'Helvetica Neue LT Pro' not found.
# findfont: Font family 'Helvetica Neue LT Pro' not found.
# findfont: Font family 'Helvetica Neue LT Pro' not found.
# findfont: Font family 'Helvetica Neue LT Pro' not found.
# findfont: Font family 'Helvetica Neue LT Pro' not found.
# findfont: Font family 'Helvetica Neue LT Pro' not found.
# findfont: Font family 'Helvetica Neue LT Pro' not found.
# findfont: Font family 'Helvetica Neue LT Pro' not found.
# findfont: Font family 'Helvetica Neue LT Pro' not found.
# findfont: Font family 'Helvetica Neue LT Pro' not found.
# findfont: Font family 'Helvetica Neue LT Pro' not found.
# findfont: Font family 'Helvetica Neue LT Pro' not found.
# findfont: Font family 'Helvetica Neue LT Pro' not found.
# findfont: Font family 'Helvetica Neue LT Pro' not found.
# findfont: Font family 'Helvetica Neue LT Pro' not found.
# findfont: Font family 'Helvetica Neue LT Pro' not found.
# findfont: Font family 'Helvetica Neue LT Pro' not found.
# findfont: Font family 'Helvetica Neue LT Pro' not found.
# findfont: Font family 'Helvetica Neue LT Pro' not found.
# findfont: Font family 'Helvetica Neue LT Pro' not found.
# findfont: Font family 'Helvetica Neue LT Pro' not found.
# findfont: Font family 'Helvetica Neue LT Pro' not found.
# findfont: Font family 'Helvetica Neue LT Pro' not found.
# findfont: Font family 'Helvetica Neue LT Pro' not found.
# findfont: Font family 'Helvetica Neue LT Pro' not found.
# findfont: Font family 'Helvetica Neue LT Pro' not found.
# findfont: Font family 'Helvetica Neue LT Pro' not found.
# findfont: Font family 'Helvetica Neue LT Pro' not found.
# findfont: Font family 'Helvetica Neue LT Pro' not found.
# findfont: Font family 'Helvetica Neue LT Pro' not found.
# findfont: Font family 'Helvetica Neue LT Pro' not found.
# findfont: Font family 'Helvetica Neue LT Pro' not found.
# findfont: Font family 'Helvetica Neue LT Pro' not found.
# findfont: Font family 'Helvetica Neue LT Pro' not found.
# findfont: Font family 'Helvetica Neue LT Pro' not found.
# findfont: Font family 'Helvetica Neue LT Pro' not found.
# findfont: Font family 'Helvetica Neue LT Pro' not found.
# findfont: Font family 'Helvetica Neue LT Pro' not found.
# findfont: Font family 'Helvetica Neue LT Pro' not found.
# findfont: Font family 'Helvetica Neue LT Pro' not found.
# findfont: Font family 'Helvetica Neue LT Pro' not found.
# findfont: Font family 'Helvetica Neue LT Pro' not found.
# findfont: Font family 'Helvetica Neue LT Pro' not found.
# findfont: Font family 'Helvetica Neue LT Pro' not found.
# findfont: Font family 'Helvetica Neue LT Pro' not found.
# findfont: Font family 'Helvetica Neue LT Pro' not found.
# findfont: Font family 'Helvetica Neue LT Pro' not found.
# findfont: Font family 'Helvetica Neue LT Pro' not found.
# findfont: Font family 'Helvetica Neue LT Pro' not found.
# findfont: Font family 'Helvetica Neue LT Pro' not found.
